# %%
from googleapiclient.discovery import  build
import pymongo

# %%
#API key connection

def Api_connect():



    Api_id="AIzaSyAnjiL7QUqeV1aDzcMqfjwtKjDjsj4_Tqk"

    api_service_name="youtube"
    api_version="v3"
    youtube=build(api_service_name,api_version,developerKey=Api_id)
    return youtube
youtube=Api_connect()

# %%
# get channel information

request=youtube.channels().list(
    part="snippet,ContentDetails,statistics",
    id="UCOh8QRInWH7eetY8mEzE75Q"
)
response=request.execute()

for i in response['items']:
    data=dict(channel_Name=i["snippet"]["title"])
    print(data)
# Out:
# {'channel_Name': 'FrozenReel'}

# %%
response['items'][0]['snippet']
# Out:
# {'title': 'FrozenReel',
#  'description': 'Welcome to ❄ Frozen Reel ❄\n\nAre you looking to earn money?  We are here 🙌 \n\n❄ FrozenReel ❄ helps people to Earn money online "WITHOUT Investment". We will recommend you the Best "Passive Income Jobs", Genuine Part-Time & Full-Time jobs.\n\nOur Moto is: Financially we will "Take you to Next level"  \n\n🎁 We are also conducting GIVEAWAY every month and giving FREE CASH 💸, GIFT CARDS 💳, GADGETS 📱 to our SUBSCRIBERS 💝\n\n💵 We have given more than 1 Lakh + Rupee worth GiveAways ( Includes Vouchers & Products) 💰\n\n🔥 SUBSCRIBE 🔥 our channel so that you can earn MONEY easily.\n\nDon\'t miss out any of our content\n\nStay Peace! ✌\n\n💰 I do Giveaway, because it makes me Happy 💸\n\nBusiness Enquires: contact@frozenreel.com\n\nOfficial Telegram channel : t.me/frozenreel\n\n',
#  'customUrl': '@frozenreel',
#  'publishedAt': '2020-04-17T08:11:20.522712Z',
# ...

# %%
response['items'][0]['id']
# Out:
# 'UCOh8QRInWH7eetY8mEzE75Q'

# %%
response['items'][0]['snippet']['title']
# Out:
# 'FrozenReel'

# %%
request=youtube.channels().list(
    part="snippet,ContentDetails,statistics",
    id="UCOh8QRInWH7eetY8mEzE75Q"
)
response=request.execute()

for i in response['items']:
    data=dict(channel_Name=i["snippet"]["title"],
              channel_id=i["id"])
    print(data)
# Out:
# {'channel_Name': 'FrozenReel', 'channel_id': 'UCOh8QRInWH7eetY8mEzE75Q'}

# %%
#get channels informations
def get_channels_info(channel_id):
    request=youtube.channels().list(
        part="snippet,ContentDetails,statistics",
        id=channel_id
    )
    response=request.execute()

    for i in response['items']:
        data=dict(channel_Name=i["snippet"]["title"],
                channel_id=i["id"],
                subscribers=i["statistics"]["subscriberCount"],
                views=i["statistics"]["viewCount"],
                total_videos=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                PlayList_id=i["contentDetails"]["relatedPlaylists"]["uploads"])
        return data

# %%
channel_details=get_channels_info("UCOh8QRInWH7eetY8mEzE75Q")

# %%
channel_details
# Out:
# {'channel_Name': 'FrozenReel',
#  'channel_id': 'UCOh8QRInWH7eetY8mEzE75Q',
#  'subscribers': '911000',
#  'views': '69052271',
#  'total_videos': '674',
#  'Channel_Description': 'Welcome to ❄ Frozen Reel ❄\n\nAre you looking to earn money?  We are here 🙌 \n\n❄ FrozenReel ❄ helps people to Earn money online "WITHOUT Investment". We will recommend you the Best "Passive Income Jobs", Genuine Part-Time & Full-Time jobs.\n\nOur Moto is: Financially we will "Take you to Next level"  \n\n🎁 We are also conducting GIVEAWAY every month and giving FREE CASH 💸, GIFT CARDS 💳, GADGETS 📱 to our SUBSCRIBERS 💝\n\n💵 We have given more than 1 Lakh + Rupee worth GiveAways ( Includes Vouchers & Products) 💰\n\n🔥 SUBSCRIBE 🔥 our channel so that you can earn MONEY easily.\n\nDon\'t miss out any of our content\n\nStay Peace! ✌\n\n💰 I do Giveaway, because it makes me Happy 💸\n\nBusiness Enquires: contact@frozenreel.com\n\nOfficial Telegram channel : t.me/frozenreel\n\n',
# ...

# %%
data
# Out:
# {'channel_Name': 'FrozenReel', 'channel_id': 'UCOh8QRInWH7eetY8mEzE75Q'}

# %%
#how to get playlist_id
response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
# Out:
# 'UUOh8QRInWH7eetY8mEzE75Q'

# %%
response=youtube.channels().list(id="UCOh8QRInWH7eetY8mEzE75Q",
                                 part="contentDetails").execute()
PlayList_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# c:\Users\PriyaSakthi\OneDrive\Desktop\NaHa project 1\youtubetest.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/PriyaSakthi/OneDrive/Desktop/NaHa%20project%201/youtubetest.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> response=youtube.channels().list(id="UCOh8QRInWH7eetY8mEzE75Q",
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PriyaSakthi/OneDrive/Desktop/NaHa%20project%201/youtubetest.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>                                  part="contentDetails").execute()
#       <a href='vscode-notebook-cell:/c%3A/Users/PriyaSakthi/OneDrive/Desktop/NaHa%20project%201/youtubetest.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> PlayList_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
#
# ...

# %%
PlayList_id
# Out:
# 'UUOh8QRInWH7eetY8mEzE75Q'

# %%
#get video ids

response=youtube.channels().list(id='UCOh8QRInWH7eetY8mEzE75Q',
                                 part='contentDetails').execute()
PlayList_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

response1=youtube.playlistItems().list(
                                    part='snippet',
                                    playlistId=PlayList_id).execute()

# %%
response1
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'nMvXl_Sa5SoMpyOrVDnU3-9ywjg',
#  'nextPageToken': 'EAAaI1BUOkNBVWlFREV5UlVaQ00wSXhRelUzUkVVMFJURW9BVkFC',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'xSpqyjBGGOSa5_GJKW51hvd4mpI',
#    'id': 'VVVPaDhRUkluV0g3ZWV0WThtRXpFNzVRLnNfRDNZSW9jQTc4',
#    'snippet': {'publishedAt': '2023-11-29T08:00:24Z',
#     'channelId': 'UCOh8QRInWH7eetY8mEzE75Q',
#     'title': '🔴 EARN from AMAZON PRIME VIDEO 🔶 Earn : Rs 1100 🔥 NO Min Withdraw | New Earning App | Work From Home',
# ...

# %%
#how to get all videos id's:
def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                        part='contentDetails').execute()
    PlayList_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None
    while True:
        response1=youtube.playlistItems().list(
                                                part='snippet',
                                                playlistId=PlayList_Id,
                                                maxResults=50,
                                                pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
                video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken') 

        if next_page_token is None:
           break
    return video_ids

# %%
Video_Ids=get_videos_ids('UCOh8QRInWH7eetY8mEzE75Q')

# %%
Video_Ids
# Out:
# ['s_D3YIocA78',
#  'y91rnzC46Bw',
#  'ltqCk8U2_mU',
#  'XNijI7mSlNQ',
#  'pEzaosoGshc',
#  'cwtM_gcK5kI',
#  'ufdPW4jBAJk',
#  'qCcMatA-q5k',
#  'tyZ-dobmZuk',
#  'LIcCV0v2O3M',
#  '_6y0ePdnzh8',
#  'CbptQBpzjJ0',
#  'bUVkH1zJffA',
#  'H-53UHANcFM',
#  '_Hrv6_bK6J0',
#  'pOCd78Ws4zI',
#  '5GJv11XbmBc',
#  'suAPCXgzXAg',
#  '7sts4rkapRU',
#  'w3Owrsigm38',
#  'uoozUEqLYCU',
#  'HSwRU81h_jA',
#  'xnXu9nFO5D4',
#  'tdirmg3LD-w',
#  'zsS9wk3Klbs',
#  'bDrHdMPN9K8',
#  'CwG0zv68f1k',
#  'CRBlqIOXwHc',
#  'uKJj7djuXUw',
#  'vUJ212VlCLA',
#  'bIzw9NmRP2o',
#  'RYZ2Ze7QdNY',
#  'PrthUdQIkfY',
#  'ViaxmLLAK3s',
#  'Ok-iZCjcBJo',
#  'Icy6XCeKMYA',
#  '0y4xn5ocNFk',
#  'vfYXvoS2pr4',
#  'lBnI8MAt-ZI',
#  '56b--Ts5ibw',
#  'zb4tdCqb59E',
#  'EuWn6YYOd9w',
#  'BU2MS1jn4qU',
#  'M0mC-B35WrM',
#  'V1P1ADxYEUs',
#  'mKk73h7YbYw',
#  'Pv2iae4ObqM',
#  'vYw5I1ZrvqQ',
#  'RDmuoxeDuoU',
#  '4wwWVath_a0',
#  'o70bk_cqb9o',
#  'L5VEvncWDE8',
#  'MdBOuWnGJnE',
#  '6pjELyTpUpk',
#  'E3bDUmu-ta0',
# ...

# %%
len(Video_Ids)
# Out:
# 674

# %%
Video_Ids
# Out:
# ['s_D3YIocA78',
#  'y91rnzC46Bw',
#  'ltqCk8U2_mU',
#  'XNijI7mSlNQ',
#  'pEzaosoGshc',
#  'cwtM_gcK5kI',
#  'ufdPW4jBAJk',
#  'qCcMatA-q5k',
#  'tyZ-dobmZuk',
#  'LIcCV0v2O3M',
#  '_6y0ePdnzh8',
#  'CbptQBpzjJ0',
#  'bUVkH1zJffA',
#  'H-53UHANcFM',
#  '_Hrv6_bK6J0',
#  'pOCd78Ws4zI',
#  '5GJv11XbmBc',
#  'suAPCXgzXAg',
#  '7sts4rkapRU',
#  'w3Owrsigm38',
#  'uoozUEqLYCU',
#  'HSwRU81h_jA',
#  'xnXu9nFO5D4',
#  'tdirmg3LD-w',
#  'zsS9wk3Klbs',
#  'bDrHdMPN9K8',
#  'CwG0zv68f1k',
#  'CRBlqIOXwHc',
#  'uKJj7djuXUw',
#  'vUJ212VlCLA',
#  'bIzw9NmRP2o',
#  'RYZ2Ze7QdNY',
#  'PrthUdQIkfY',
#  'ViaxmLLAK3s',
#  'Ok-iZCjcBJo',
#  'Icy6XCeKMYA',
#  '0y4xn5ocNFk',
#  'vfYXvoS2pr4',
#  'lBnI8MAt-ZI',
#  '56b--Ts5ibw',
#  'zb4tdCqb59E',
#  'EuWn6YYOd9w',
#  'BU2MS1jn4qU',
#  'M0mC-B35WrM',
#  'V1P1ADxYEUs',
#  'mKk73h7YbYw',
#  'Pv2iae4ObqM',
#  'vYw5I1ZrvqQ',
#  'RDmuoxeDuoU',
#  '4wwWVath_a0',
#  'o70bk_cqb9o',
#  'L5VEvncWDE8',
#  'MdBOuWnGJnE',
#  '6pjELyTpUpk',
#  'E3bDUmu-ta0',
# ...

# %%
#get video information
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id= video_id
        )
        response=request.execute()

        for item in response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item.get('tags'),
                    Thumbnail=item['snippet']['thumbnails'],
                    Descripion=item.get('description'),
                    Published_date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item.get('viewCount'),
                    Comments=item.get('commentCount'),
                    Favorite_Count=item['statistics']['favoriteCount'],
                    Definition=item['contentDetails']['definition'],
                    Caption_status=item['contentDetails']['caption']
                    )
            video_data.append(data)
    return video_data

# %%
#for i in video_data:
    #print(i)

# %%
video_details=get_video_info(Video_Ids)

# %%
#for i in Video_data:
    #print(i)

# %%
len(video_details)
# Out:
# 674

# %%
#get comment information
def get_channels_info(video_ids):
    comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response=request.execute()
            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Authour=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])

                comment_data.append(data)
    except:
        pass
    return comment_data

# %%
comment_details=get_channels_info(Video_Ids)

# %%
comment_details
# Out:
# [{'Comment_Id': 'UgwzMqt0A1Blr8M10U94AaABAg',
#   'Video_Id': 's_D3YIocA78',
#   'Comment_Text': '❤️ Website Link : <a href="https://bit.ly/47w6BZy">https://bit.ly/47w6BZy</a><br><br>🎁 Bonus App : <a href="https://youtu.be/_6y0ePdnzh8?si=ZNGvWXDOoMlBBF4O">https://youtu.be/_6y0ePdnzh8?si=ZNGvWXDOoMlBBF4O</a>',
#   'Comment_Authour': '@FrozenReel',
#   'Comment_Published': '2023-11-29T07:59:10Z'},
#  {'Comment_Id': 'UgwbQNHTQ0AOOygh0Ad4AaABAg',
#   'Video_Id': 's_D3YIocA78',
#   'Comment_Text': 'Hii',
#   'Comment_Authour': '@RUBANDALEX',
#   'Comment_Published': '2023-11-29T12:08:55Z'},
#  {'Comment_Id': 'UgyTTmTIDD_UD5KaTOx4AaABAg',
#   'Video_Id': 's_D3YIocA78',
#   'Comment_Text': 'Akka ..I am already working in an company. Shall I apply for this job.',
#   'Comment_Authour': '@angelinmaryangelinmary2178',
#   'Comment_Published': '2023-11-29T11:56:20Z'},
#  {'Comment_Id': 'UgyfdlSf7hNGNkojrON4AaABAg',
#   'Video_Id': 's_D3YIocA78',
#   'Comment_Text': 'hi',
# ...

# %%
#get_playlist_details
def get_playlist_details(channel_id):

        next_page_token=None
        All_Data=[]
        while True:
                request=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()

                for item in response['items']:
                        data=dict(PlayList_Id=item['id'],
                                Tittle=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_Count=item['contentDetails']['itemCount'])
                        All_Data.append(data)

                next_Page_Token=response.get('nextPageToken')
                if next_Page_Token is None:
                        break
                return  All_Data

# %%
playlist_details=get_playlist_details('UCQSbjDZOCsJfsddQm9b4PZg')

# %%
playlist_details
# Out:
# [{'PlayList_Id': 'PLIEZAJqKws4b4qXUI9jdN_SnDprqIBU3s',
#   'Tittle': 'after hayabusa accident',
#   'Channel_Id': 'UCQSbjDZOCsJfsddQm9b4PZg',
#   'Channel_Name': 'Twin Throttlers',
#   'PublishedAt': '2023-11-16T03:24:05Z',
#   'Video_Count': 4},
#  {'PlayList_Id': 'PLIEZAJqKws4amsvr9m-xBFY_lNFuFNvNI',
#   'Tittle': 'hayabusa accident',
#   'Channel_Id': 'UCQSbjDZOCsJfsddQm9b4PZg',
#   'Channel_Name': 'Twin Throttlers',
#   'PublishedAt': '2023-11-04T01:56:38Z',
#   'Video_Count': 2},
#  {'PlayList_Id': 'PLIEZAJqKws4bm5Dj73hP2SIdM6H9QBp1V',
#   'Tittle': '♥️Mini Jarvis',
#   'Channel_Id': 'UCQSbjDZOCsJfsddQm9b4PZg',
#   'Channel_Name': 'Twin Throttlers',
#   'PublishedAt': '2023-08-11T01:28:25Z',
#   'Video_Count': 1},
#  {'PlayList_Id': 'PLIEZAJqKws4axPzF1YdicP_ggTmXHhX5m',
#   'Tittle': '😈Super bike Ownership Review♥️',
#   'Channel_Id': 'UCQSbjDZOCsJfsddQm9b4PZg',
#   'Channel_Name': 'Twin Throttlers',
#   'PublishedAt': '2023-08-09T15:37:20Z',
#   'Video_Count': 1},
# ...

# %%
len(playlist_details)
# Out:
# 50

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'MmYCt5MHzYq_5M_P5rgxXfq_eow',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'fNaEH76YQHWS2F6BRG4mrW3L450',
#    'id': 'UCOh8QRInWH7eetY8mEzE75Q',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUOh8QRInWH7eetY8mEzE75Q'}}}]}

# %%
client=pymongo.MongoClient("mongodb+srv://RXNaHa:nagasiva@cluster0.kfkmlw7.mongodb.net/?retryWrites=true&w=majority")
db=client["Youtube"]
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# c:\Users\PriyaSakthi\OneDrive\Desktop\NaHa project 1\youtubetest.ipynb Cell 35 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PriyaSakthi/OneDrive/Desktop/NaHa%20project%201/youtubetest.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> client=pymongo.MongoClient("mongodb+srv://RXNaHa:nagasiva@cluster0.kfkmlw7.mongodb.net/?retryWrites=true&w=majority")
#       <a href='vscode-notebook-cell:/c%3A/Users/PriyaSakthi/OneDrive/Desktop/NaHa%20project%201/youtubetest.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> db=client["Youtube"]
#
# File c:\Users\PriyaSakthi\OneDrive\Desktop\NaHa project 1\.venv\lib\site-packages\pymongo\mongo_client.py:771, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     767 if timeout is not None:
#     768     timeout = common.validate_timeout_or_none_or_zero(
# ...
